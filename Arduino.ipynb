# %%
#data/doucments loading (rag implemention)
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("Arduino_datasheet.pdf")
pdf_loader = loader.load()
print(pdf_loader[0])
# Out:
# page_content='User Manual
# SKU: A000066
# Description
# The Arduino® UNO R3 is the perfect board to get familiar with electronics and coding. This versatile development
# board is equipped with the well-known ATmega328P and the ATMega 16U2 Processor.
# This board will give you a great ﬁrst experience within the world of Arduino.
# Target areas:
# Maker, introduction, industries
# Arduino® UNO R3
# 1 / 26 Arduino® UNO R3 Modiﬁed: 17/08/2026' metadata={'producer': 'Skia/PDF m151', 'creator': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/151.0.0.0 Safari/537.36', 'creationdate': '2026-08-17T06:56:00+00:00', 'title': 'localhost:8123/A000066/haz7a-datasheet.html', 'moddate': '2026-08-17T06:56:00+00:00', 'source': 'Arduino_datasheet.pdf', 'total_pages': 26, 'page': 0, 'page_label': '1'}

# %%
#ocument splitting
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_loader = PyPDFLoader("Arduino_datasheet.pdf")
documents = text_loader.load()
text_splitter = RecursiveCharacterTextSplitter( chunk_size=200,chunk_overlap=0)
final_docduments = text_splitter.split_documents(documents)
final_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m151', 'creator': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/151.0.0.0 Safari/537.36', 'creationdate': '2026-08-17T06:56:00+00:00', 'title': 'localhost:8123/A000066/haz7a-datasheet.html', 'moddate': '2026-08-17T06:56:00+00:00', 'source': 'Arduino_datasheet.pdf', 'total_pages': 26, 'page': 0, 'page_label': '1'}, page_content='User Manual\nSKU: A000066\nDescription\nThe Arduino® UNO R3 is the perfect board to get familiar with electronics and coding. This versatile development'),
# ...

# %%
#embedding means converting textual data into token(vectors)
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 10627.11it/s]

# %%
#embedding and vector stores in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(final_documents, embeddings)
db

# %%
#Retrival(similarity search) 
query =  input("Enter your questions for c++: ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# 7 FCC Caution
# Any Changes or modiﬁcations not expressly approved by the party responsible for compliance could void the user’s
# authority to operate the equipment.
# This device complies with part 15 of the FCC Rules. Operation is subject to the following two conditions:
# (1) This device may not cause harmful interference
# (2) this device must accept any interference received, including interference that may cause undesired operation.
# FCC RF Radiation Exposure Statement:
# English: User manuals for license-exempt radio apparatus shall contain the following or equivalent notice in a
